# %% [markdown]
# Run the Debt Fraction calculations to update debt fraction in the ATB workbook based on changes to incentive levels

# %%
# Install requirements (only do this once)
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached click-8.1.6-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached exceptiongroup-1.1.2-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached packaging-23.1-py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached pluggy-1.2.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached pytest-7.4.0-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached xlwings-0.31.3-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# ...
# Using cached click-8.1.6-py3-none-any.whl (97 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Using cached exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Using cached lxml-4.9.3-cp311-cp311-win_amd64.whl (3.8 MB)
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
# ...

# %% [markdown]
# #### Calculate Debt Fractions for no IRA case
#
# We run these for Land Based Wind and Utility PV. There appears to be a bug in the offshore wind calculation, so we'll use the Land Based Wind debt factor instead. The baseline debt factors for land-based wind and offshore wind are relatively close in the nearer years (48% for LBW and 51% for OSW). Though they diverge in later years, the LBW DF should be a close enough approximation.

# %%
#### Debt Fractions for No-IRA case

# %%
### No IRA Debt Fractions
! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\1_noIRA_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\1_noIRA Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\1_noIRA_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\1_noIRA Debt Ratio UPV.csv"
# Out:
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case R&D
# Loading data from Land-Based Wind, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case Market
# Loading data from Solar - Utility PV, for Market and 20
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\noah.verbeek\Documents\ATB-calc\debt_fraction_calculator\debt_fraction_calc.py", line 329, in <module>
#     calculate_all_debt_fractions() # pylint: disable=no-value-for-parameter
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\noah.verbeek\anaconda3\Lib\site-packages\click\core.py", line 1157, in __call__
# ...

# %% [markdown]
# #### Debt Fractions for Base IRA case

# %%
! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\2_BaseIRA_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\2_BaseIRA_ITC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\2_BaseIRA_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\2_BaseIRA_ITC Debt Ratio UPV.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\2_BaseIRA_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\2_BaseIRA_PTC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\2_BaseIRA_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\2_BaseIRA_PTC Debt Ratio UPV.csv"
# Out:
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case R&D
# Loading data from Land-Based Wind, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case Market
# Loading data from Solar - Utility PV, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case R&D
# Loading data from Solar - Utility PV, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# ...

# %% [markdown]
# #### Calculate Debt Fractions for IRA Wage case

# %%
! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\3_IRAWage_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\3_IRAWage_ITC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\3_IRAWage_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\3_IRAWage_ITC Debt Ratio UPV.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\3_IRAWage_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\3_IRAWage_PTC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\3_IRAWage_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\3_IRAWage_PTC Debt Ratio UPV.csv"
# Out:
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case R&D
# Loading data from Land-Based Wind, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case Market
# Loading data from Solar - Utility PV, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case R&D
# Loading data from Solar - Utility PV, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# ...

# %% [markdown]
# #### Calculate Debt Fractions for IRA Domestic Content Bonus case

# %%
! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\4_IRADC_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\4_IRADC_ITC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\4_IRADC_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\4_IRADC_ITC Debt Ratio UPV.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\4_IRADC_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\4_IRADC_PTC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\4_IRAWage_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\4_IRADC_PTC Debt Ratio UPV.csv"
# Out:
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case R&D
# Loading data from Land-Based Wind, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case Market
# Loading data from Solar - Utility PV, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case R&D
# Loading data from Solar - Utility PV, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# ...

# %% [markdown]
# #### Calculate Debt Fractions for IRA Both Bonus case

# %%
! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\5_IRAMax_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\5_IRAMax_ITC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\5_IRAMax_ITC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\5_IRAMax_ITC Debt Ratio UPV.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech LandBasedWindProc \
    "ATB Files\5_IRAMax_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\5_IRAMax_PTC Debt Ratio LBW.csv"

! python -m  debt_fraction_calculator.debt_fraction_calc --tech UtilityPvProc \
    "ATB Files\5_IRAWage_PTC_2024 v2 Annual Technology Baseline Workbook Errata 7-19-2024.xlsx" \
    "ATB Files\New Debt Ratios\5_IRAMax_PTC Debt Ratio UPV.csv"
# Out:
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case R&D
# Loading data from Land-Based Wind, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case Market
# Loading data from Solar - Utility PV, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech UtilityPV and financial case R&D
# Loading data from Solar - Utility PV, for R&D and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# Processing tech LandbasedWind and financial case Market
# Loading data from Land-Based Wind, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
# ...
